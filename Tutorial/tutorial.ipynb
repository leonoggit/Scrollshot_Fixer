# %%
# !pip uninstall echogains -y
# !pip install git+https://github.com/GillesVanDeVyver/EchoGAINS.git
# Out:
# Found existing installation: echogains 1.0.1
# Uninstalling echogains-1.0.1:
#   Successfully uninstalled echogains-1.0.1
# Collecting git+https://github.com/GillesVanDeVyver/EchoGAINS.git
#   Cloning https://github.com/GillesVanDeVyver/EchoGAINS.git to /tmp/pip-req-build-6du87lpl
#   Running command git clone --filter=blob:none --quiet https://github.com/GillesVanDeVyver/EchoGAINS.git /tmp/pip-req-build-6du87lpl
#   Resolved https://github.com/GillesVanDeVyver/EchoGAINS.git to commit 376f9ef693661d1198e87d6b9f30606f870df8a4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: blobfile>=0.1.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from echogains==1.0.1) (3.0.0)
# Requirement already satisfied: huggingface_hub>=0.8.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from echogains==1.0.1) (0.27.0)
# Requirement already satisfied: numpy>=2.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from echogains==1.0.1) (2.2.3)
# Requirement already satisfied: opencv-python>=4.9 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from echogains==1.0.1) (4.11.0.86)
# Requirement already satisfied: scikit-image>=0.20 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from echogains==1.0.1) (0.23.2)
# Requirement already satisfied: torch>=1.10 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from echogains==1.0.1) (2.6.0)
# Requirement already satisfied: tqdm>=4.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from echogains==1.0.1) (4.65.0)
# Requirement already satisfied: pycryptodomex>=3.8 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from blobfile>=0.1.0->echogains==1.0.1) (3.21.0)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from blobfile>=0.1.0->echogains==1.0.1) (1.26.18)
# Requirement already satisfied: lxml>=4.9 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from blobfile>=0.1.0->echogains==1.0.1) (5.3.1)
# Requirement already satisfied: filelock>=3.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from blobfile>=0.1.0->echogains==1.0.1) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from huggingface_hub>=0.8.0->echogains==1.0.1) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from huggingface_hub>=0.8.0->echogains==1.0.1) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from huggingface_hub>=0.8.0->echogains==1.0.1) (6.0.1)
# Requirement already satisfied: requests in /home/gillesv/miniconda3/lib/python3.11/site-packages (from huggingface_hub>=0.8.0->echogains==1.0.1) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from huggingface_hub>=0.8.0->echogains==1.0.1) (4.12.1)
# Requirement already satisfied: scipy>=1.9 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from scikit-image>=0.20->echogains==1.0.1) (1.14.1)
# Requirement already satisfied: networkx>=2.8 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from scikit-image>=0.20->echogains==1.0.1) (3.3)
# Requirement already satisfied: pillow>=9.1 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from scikit-image>=0.20->echogains==1.0.1) (10.3.0)
# Requirement already satisfied: imageio>=2.33 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from scikit-image>=0.20->echogains==1.0.1) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from scikit-image>=0.20->echogains==1.0.1) (2024.5.22)
# Requirement already satisfied: lazy-loader>=0.4 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from scikit-image>=0.20->echogains==1.0.1) (0.4)
# Requirement already satisfied: jinja2 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from torch>=1.10->echogains==1.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.10->echogains==1.0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from jinja2->torch>=1.10->echogains==1.0.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from requests->huggingface_hub>=0.8.0->echogains==1.0.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from requests->huggingface_hub>=0.8.0->echogains==1.0.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from requests->huggingface_hub>=0.8.0->echogains==1.0.1) (2023.11.17)
# Building wheels for collected packages: echogains
#   Building wheel for echogains (pyproject.toml) ... done
#   Created wheel for echogains: filename=echogains-1.0.1-py3-none-any.whl size=114493 sha256=7c9032b118d809346196a350919c827e400c08ae760c7396f36aa1af92ae2504
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kq900kob/wheels/2f/c2/d3/aba28b3e8edc4876731fd918ca71dd4dd673f06d400895ca98
# Successfully built echogains
# Installing collected packages: echogains
# Successfully installed echogains-1.0.1

# %%
# Set seed for reproducibility
import numpy as np
np.random.seed(2025)

# %%
# Install matplotlib to plot results in toturial
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/gillesv/miniconda3/lib/python3.11/site-packages (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/gillesv/miniconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Donwload a small sample of test data
# This will download +-240Mb of data under ./local__data/sample_data
import os
import echogains
current_directory = os.getcwd()
download_loc = os.path.join(current_directory,"local_data")
echogains.download_data_sample(download_loc,verbose=True)
# Out:
# Fetching contents from: https://api.github.com/repos/GillesVanDeVyver/us_cardiac_sample_data/contents/sample_data
# Fetching contents from: https://api.github.com/repos/GillesVanDeVyver/us_cardiac_sample_data/contents/sample_data_seg
#  17%|███████▌                                     | 1/6 [00:00<00:04,  1.18it/s]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data/a2c.mp4
#  33%|███████████████                              | 2/6 [00:07<00:17,  4.48s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data/a2c.npy
#  50%|██████████████████████▌                      | 3/6 [00:08<00:08,  2.68s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data/a4c.mp4
#  67%|██████████████████████████████               | 4/6 [00:16<00:09,  4.65s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data/a4c.npy
#  83%|█████████████████████████████████████▌       | 5/6 [00:16<00:03,  3.25s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data/alax.mp4
# 100%|█████████████████████████████████████████████| 6/6 [00:23<00:00,  3.95s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data/alax.npy
#  33%|███████████████                              | 1/3 [00:01<00:02,  1.18s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data_seg/a2c.npy
#  67%|██████████████████████████████               | 2/3 [00:02<00:01,  1.26s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data_seg/a4c.npy
# 100%|█████████████████████████████████████████████| 3/3 [00:03<00:00,  1.20s/it]
# Downloaded: /home/gillesv/PycharmProjects/EchoGAINS/tutorial/local_data/sample_data_seg/alax.npy

# %%
# Load a sample
import os
import matplotlib.pyplot as plt
sample_a2c = np.load(os.path.join(download_loc,"sample_data/a2c.npy"))
# sample_a2c is an ndarray of shape (nb_frames,height,width) with values in range [0,255]
sample_frame = sample_a2c[-1]
sample_a2c_seg = np.load(os.path.join(download_loc,"sample_data_seg/a2c.npy"),allow_pickle=True)
# sample_a2c_seg is an ndarray of shape (nb_frames,height,width) with values in range [0,4]
# 0: background, 1: left ventricle, 2: myocardium, 3: left atrium
frame_seg = sample_a2c_seg[-1]
visual = echogains.create_visualization(sample_frame,frame_seg)
plt.imshow(visual)
plt.show()

# %%
'''
# EchoGAINS works with datasets that have the following structure:
├── images
│   ├── frame1.png
│   ├── frame2.png
│   ├── ...
├── labels
│   ├── frame1.png
│   ├── frame2.png
│   ├── ...
The images folder should contain the bmode images as grayscale pngs.
The labels folder should contains the labels with the following convention:
0: background, 1: left ventricle, 2: myocardium, 3: left atrium

Let's create a simple dataset of a few frames in this format from the sample data we downloaded.
'''
import os
import numpy as np
from PIL import Image
from skimage.transform import resize
from tqdm import tqdm

## some helper functions
def save_as_image(np_array,path):
    """
    Save a 2D numpy array as a grayscale image (only 1 channel)
    :param np_array: np.array of size (W,H)
        The array to save
    :param path: str
        The path to sae the array to
    """
    img_data = Image.fromarray(np_array)
    img_data = img_data.convert("L")
    img_data.save(path)

def create_dataset(sample_frames, sample_segments, output_dir, num_frames=5):
    """
    Create a dataset from the given sample frames and segments.
    The function will select num_frames random frames from the sample frames and save them to the output_dir.
    :param sample_frames: np.array of shape (nb_frames, height, width)
        The sample frames
    :param sample_segments: np.array of shape (nb_frames, height, width)
        The sample segments
    :param output_dir: str
        The output directory to save the dataset to
    :param num_frames: int
        The number of frames to save
    """
    nb_frames = sample_frames.shape[0]
    assert nb_frames == sample_segments.shape[0], "Number of frames in sample_frames and sample_segments should be equal."
    image_dir = os.path.join(output_dir, "images")
    label_dir = os.path.join(output_dir, "labels")
    os.makedirs(image_dir, exist_ok=True)
    os.makedirs(label_dir, exist_ok=True)

    for i in tqdm(range(num_frames)):
        # sample a ramdom frame
        idx = np.random.randint(nb_frames)
        frame = sample_frames[idx]
        seg = sample_segments[idx]

        # save frame
        frame_path = os.path.join(image_dir, f"frame{i}.png")
        save_as_image(frame, frame_path)

        # save segmentation
        seg_path = os.path.join(label_dir, f"frame{i}.png")
        save_as_image(seg, seg_path)

# Define output dataset path
custom_dataset_path = os.path.join(download_loc, "custom_dataset")
label_path=os.path.join(custom_dataset_path, "labels")
images_path = os.path.join(custom_dataset_path, "images")

# resize sample_a2c to (256,256)
sample_a2c = resize(sample_a2c, (sample_a2c.shape[0], 256, 256), preserve_range=True)
# Create dataset
nb_frames=5
create_dataset(sample_a2c, sample_a2c_seg, custom_dataset_path, num_frames=nb_frames)
# Out:
# 100%|████████████████████████████████████████████| 5/5 [00:00<00:00, 248.21it/s]

# %%
'''
Now we prepare the custom dataset for generative augmentation.
The script below creates the following structure inside the download_loc folder:
├── custom_dataset_augmented
│   ├── images
│   │   ├── frame0.png
│   │   ├── frame1.png
│   │   ├── ...
│   ├── labels
│   │   ├── frame0.png
│   │   ├── frame0_aug0.png
│   │   ├── frame0_aug1.png
│   │   ├── ...
│   │   ├── frame1.png
│   │   ├── frame1_aug0.png
│   │   ├── ...
│   ├── repaint
│   │   ├── keep
│   │   │   ├── frame0.png
│   │   │   ├── frame1.png
│   │   │   ├── ...
│   │   ├── masks
│   │   │   ├── frame0.png
│   │   │   ├── frame1.png
│   │   │   ├── ...
The keep folder in repaint contains the transformed images with the pixels that are kept.
The masks folder in repaint contains the masks of the transformed images. This tells repaint which pixels to keep.
'''
repaint_keep_path = os.path.join(download_loc, "repaint", "keep")
repaint_masks_path = os.path.join(download_loc, "repaint", "masks")
augmented_dataset_path = os.path.join(download_loc, "custom_dataset_augmented")

augmentation_params= [
    {'type': 'depth', 'prob': 0.5, 'depth_increase_range': [0,150] }, # increase depth by 0 to 150 pixels
    {'type': 'rotation', 'prob': 0.5, 'rotation_range': [-30, 30]}, # rotate image by -30 to 30 degrees
    {'type': 'sector_width', 'prob': 0.5, 'width_factor': [0.5, 1.5]}, # change sector width by factor 0,5 to 1.5
    {'type': 'translation', 'prob': 0.5, 'displacement_radius_range': [0, 50]} # translate image by a distance between 0 to 50 pixels in a random direction
] # all augmentations are applied with a probability of 50%
nb_augmentations = 5 # create 5 augmented images for each original image in the dataset

echogains.prepare_gen_aug_seg(custom_dataset_path,
                            augmented_dataset_path,
                            repaint_keep_path,
                            repaint_masks_path,
                            augmentation_params,
                            nb_augmentations,
                            include_original=True)
# Out:
# 100%|█████████████████████████████████████████████| 5/5 [00:00<00:00,  7.27it/s]

# %%
# let's plot a sample from the repaint/keep and repaint/masks folders to illustrate
import matplotlib.pyplot as plt
import os

# Load a png from repaint/keep. This is the transformed image with the pixels that are kept.
sample_keep = plt.imread(os.path.join(repaint_keep_path, "frame0_aug1.png"))
plt.imshow(sample_keep, cmap='gray')
plt.show()

# Load a png from repaint/masks. This is the mask of the transformed image. This tells repaint which pixels to keep
# and which to repaint.
sample_mask = plt.imread(os.path.join(repaint_masks_path, "frame0_aug1.png"))
plt.imshow(sample_mask, cmap='gray')
plt.show()

# the generative model will repaint everything that falls outside the mask in the transformed image

# %%
# Now we run RePaint inference
# First, we need to download a nodel trained on CAMUS from HuggingFace
echogains.download_and_set_up_model('CAMUS_diffusion_model')

# buffer_path is the directory used for temporary storage during inference
buffer_path = os.path.join(download_loc, "repaint", "buffer")
nb_files_in_dataset = nb_frames * nb_augmentations
aug_output_path=os.path.join(augmented_dataset_path, "images")

# Now we run RePaint inference
config = echogains.load_default_config('CAMUS_diffusion_model',repaint_keep_path,repaint_masks_path,
                                       buffer_path,aug_output_path)

echogains.run_repaint(config)
# Out:
# Download link for model CAMUS_diffusion_model is ('gillesvdv/CAMUS_diffusion_model', 'CAMUS_diffusion_model.pt')
# Downloading CAMUS_diffusion_model.pt from Hugging Face repository gillesvdv/CAMUS_diffusion_model...
# Model downloaded to /home/gillesv/miniconda3/lib/python3.11/site-packages/echogains/models/models--gillesvdv--CAMUS_diffusion_model/snapshots/42be9f6b7ace0a56408c7c52a57342cf7e28a8a8/CAMUS_diffusion_model.pt
# Copied /home/gillesv/miniconda3/lib/python3.11/site-packages/echogains/models/models--gillesvdv--CAMUS_diffusion_model/snapshots/42be9f6b7ace0a56408c7c52a57342cf7e28a8a8/CAMUS_diffusion_model.pt to /home/gillesv/miniconda3/lib/python3.11/site-packages/echogains/models
# Model CAMUS_diffusion_model.pt set up successfully!
# Start camus_all
# Total number of parameters in model: 41125062
# sampling...
# batch: 0
#   0%|          | 0/4570 [00:00<?, ?it/s]
# sampling complete

# %%
# Let's visualize a sample of the dataset and it's augmentations

fig, axs = plt.subplots(1, nb_augmentations+1, figsize=(20, 10))

original_sample = 'frame0'

# Load the original image
original_img = plt.imread(os.path.join(images_path, f"{original_sample}.png"))
original_label = plt.imread(os.path.join(label_path, f"{original_sample}.png"))
original_label=(256*original_label).astype(np.uint8)

original_visual = echogains.create_visualization(original_img, original_label)


axs[0].imshow(original_visual)
axs[0].set_title("Original")



# Load the augmented images
for i in range(nb_augmentations):
    augmented_img = plt.imread(os.path.join(augmented_dataset_path, "images", f"{original_sample}_aug{i}.png"))
    augmented_img=augmented_img[:,:,0] # rgb to grayscale
    augmented_label = plt.imread(os.path.join(augmented_dataset_path, "labels", f"{original_sample}_aug{i}.png"))
    augmented_label=(256*augmented_label).astype(np.uint8)
    augmented_visual = echogains.create_visualization(augmented_img, augmented_label)
    axs[i+1].imshow(augmented_visual)


# remove axis
for ax in axs:
    ax.axis('off')
plt.show()
